# %% [markdown]
# <a href="https://colab.research.google.com/github/Rasheena-Arimbrathodi/BBC-web-scraping-using-requests-and-beautiful-soup/blob/main/YouTube_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests youtube-transcript-api

# %%
import requests

api_key=""
video_id=""
url=f""
response=requests.get(url)
if response.status_code==200:
  video_info=response.json()
  print(video_info)
else:
  print("error")
